# %%
import pandas as pd
import numpy as np

# restaurants_limited_features
df_res = pd.read_csv("/Users/dima/code/Dimasaur/scorecast/data/restaurants_limited_features.csv")

# restaurant ids dataset
res_ids = pd.read_csv("/Users/dima/code/Dimasaur/scorecast/data/restaurants.csv")

# yelp general business dataset
business_json_path = "/Users/dima/code/Dimasaur/scorecast/data/yelp_academic_dataset_business.json"

#reading the json file
df_business_raw = pd.read_json(business_json_path, lines=True)

# creating a destination path
csv_file_path_review = "yelp_business_raw.csv"

#converting the output into a csv file
df_business_raw.to_csv(csv_file_path_review, index=False)



df_res['food_type_string'] = df_res['food_type'].apply(lambda x: str(x).strip('[]'))
df_res['food_type_string'] = df_res['food_type_string'].apply(lambda x: str(x).replace("'",""))

# replace the values in the food_types with the top - 20 cuisines

replace_dictionary = {
    "Pizza" : "Italian",
    "Burgers, Fast Food" : "Burgers",
    "Italian, Pizza" : "Italian",
    "American (New)" : "American",
    "Fast Food, Sandwiches" : "Sandwiches",
    "American (Traditional)" : "American",
    "Fast Food, Mexican" : "Mexican",
    "Coffee & Tea, Food" : "Cafes",
    "Japanese, Sushi Bars" : "Japanese",
    "American (Traditional), Diners" : "Diners",
    "Bakeries, Food" : "Bakery",
    "Delis, Sandwiches" : "Delis",
    "Mexican, Tex-Mex" : "Mexican",
    "American (Traditional), Burgers" : "American",
    "Sushi Bars" : "Japanese",
    "Chinese, Fast Food" : "Chinese",
    "American (Traditional), Cafes" : "American",
    "Mexican, Tacos" : "Mexican",
    "Pizza, Sandwiches" : "Sandwiches",
    "Food, Pizza" : "Italian",
    "American (Traditional), Seafood" : "American",
    "Greek, Mediterranean" : "Greek",
    "American (New), American (Traditional)" : "American",
    "Cajun/Creole, Seafood" : "Cajun/Creole"

}

df_res.food_type_string = df_res.food_type_string.replace(replace_dictionary)

# generate the clea array of the top 20 categories
df_food_t20 = list(df_res.food_type_string.value_counts(normalize=True).head(25).index)
df_food_t20.remove('O')
df_food_t20.remove('')
df_food_t20 = df_food_t20[:20]

# top 20 food types
np_food_20 = np.array([df_food_t20])


# filtering the the list of business to get the restaurants only
df_restaurants = df_business_raw[df_business_raw.business_id.isin(res_ids.business_id)].reset_index(drop=True)


df_restaurants.categories_clean = df_restaurants.categories.str.replace(", ",",")

df_restaurants['food_type_one'] = None

# function that extracts a category from a column in a dataframe if that category is present in a given list


def extract_category(categories, food_types):

    # Combine the lists after splitting by space and by comma
    possible_foods = categories.split(' ') + categories.split(',')
    # Remove any empty strings that might be created by split
    possible_foods = [food.strip() for food in possible_foods if food.strip()]

    for food in possible_foods:
        if food in food_types:
            return food
    return None

df_restaurants['food_type_one'] = df_restaurants['categories'].apply(lambda x: extract_category(x, df_food_t20))

states_to_exclude = ['XMS','CO','HI','MT','NC']

df_restaurants = df_restaurants[~df_restaurants['state'].isin(states_to_exclude)]
# Out:
# /var/folders/fd/585jf60x39vflmpy4gfz7yzh0000gn/T/ipykernel_73183/1900787865.py:5: DtypeWarning: Columns (14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_res = pd.read_csv("/Users/dima/code/Dimasaur/scorecast/data/restaurants_limited_features.csv")
# /var/folders/fd/585jf60x39vflmpy4gfz7yzh0000gn/T/ipykernel_73183/1900787865.py:73: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_restaurants.categories_clean = df_restaurants.categories.str.replace(", ",",")

# %%
df_restaurants.groupby(['state','food_type_one']).stars.mean().sort_values(ascending=False).tail(50)
# Out:
# state  food_type_one
# AZ     Sandwiches       3.365613
# AB     Mexican          3.361702
# LA     Sandwiches       3.349359
# IN     Sandwiches       3.342752
# PA     Diners           3.340541
# MO     Sandwiches       3.328502
# DE     American         3.321429
# FL     Chinese          3.320175
# ID     Mexican          3.316000
# NJ     Diners           3.297297
# IL     Mexican          3.291209
# AZ     Chinese          3.280576
# TN     Italian          3.275000
# MO     Mexican          3.258278
# AB     Steakhouses      3.244186
# IL     Italian          3.241667
# AB     American         3.226316
# TN     Chinese          3.223333
# CA     Chicken Wings    3.187500
# IL     Greek            3.166667
# NV     Chinese          3.155844
# DE     Chicken Wings    3.152174
#        Chinese          3.149123
# NV     Chicken Wings    3.144737
# ID     Chinese          3.125000
# AZ     Cajun/Creole     3.090909
# IL     Sandwiches       3.086420
# LA     Chicken Wings    3.042683
# NJ     Chicken Wings    3.033333
# AB     Burgers          3.019774
# TN     Chicken Wings    3.015625
# PA     Chicken Wings    2.941799
# FL     Chicken Wings    2.937500
# ID     Chicken Wings    2.928571
# IN     Chicken Wings    2.783784
# AZ     Chicken Wings    2.771186
# ID     Burgers          2.743243
# AZ     Burgers          2.694872
# NV     Burgers          2.683333
# LA     Burgers          2.675481
# NJ     Burgers          2.651282
# IN     Burgers          2.607872
# PA     Burgers          2.607708
# MO     Chicken Wings    2.606250
# TN     Burgers          2.570288
# FL     Burgers          2.567021
# DE     Burgers          2.556818
# MO     Burgers          2.543561
# IL     Burgers          2.523148
#        Chicken Wings    2.410714
# Name: stars, dtype: float64

# %%
states_mean_review_scores = pd.DataFrame(df_restaurants.groupby(['state']).stars.mean().sort_values(ascending=False))
states_mean_review_scores.to_csv('/Users/dima/code/Dimasaur/scorecast/eda/states_mean_review_scores.csv')

# %%
unique_states = pd.DataFrame(df_restaurants['state'].unique(), columns=['state'])
unique_dtates = unique_states.state.str.upper()
unique_states = pd.DataFrame(unique_states.state.sort_values(ascending=True).reset_index(drop=True))

unique_cities = pd.DataFrame(df_restaurants['city'].unique(), columns=['city'])
unique_cities = pd.DataFrame(unique_cities.city.sort_values(ascending=True).reset_index(drop=True))

# %%
unique_cities.to_csv('cities.csv')
unique_states.to_csv('states.csv')

# %%
df_restaurants.city = df_restaurants.city.astype(str)
df_restaurants.state = df_restaurants.state.astype(str)

df_restaurants.city = df_restaurants.city.str.upper()
df_restaurants.state = df_restaurants.state.str.upper()

# %%
df_restaurants.state.value_counts()
# Out:
# state
# PA    12641
# FL     8731
# TN     4352
# MO     4247
# IN     4150
# LA     3640
# NJ     3341
# AZ     2671
# AB     2410
# NV     1673
# ID     1302
# CA     1161
# IL      983
# DE      961
# Name: count, dtype: int64

# %%
state_city_dict = df_restaurants.groupby('state')['city'].apply(set).to_dict()
state_city_dict = {state: list(cities) for state, cities in state_city_dict.items()}
state_city_dict.keys()
# Out:
# dict_keys(['AB', 'AZ', 'CA', 'DE', 'FL', 'ID', 'IL', 'IN', 'LA', 'MO', 'NJ', 'NV', 'PA', 'TN'])

# %%
import json

with open('state_city_dict.json', 'w') as json_file:
    json.dump(state_city_dict, json_file, indent=4)

# %%
state_names = {
    'AB': 'ALBERTA',
    'AZ': 'ARIZONA',
    'CA': 'CALIFORNIA',
    'DE': 'DELAWARE',
    'FL': 'FLORIDA',
    'ID': 'IDAHO',
    'IL': 'ILLINOIS',
    'IN': 'INDIANA',
    'LA': 'LOUISIANA',
    'MO': 'MISSOURI',
    'NJ': 'NEW JERSEY',
    'NV': 'NEVADA',
    'PA': 'PENNSYLVANIA',
    'TN': 'TENNESSEE'
}

state_names.values
# for key in list(state_city_dict.keys()):
#     if key in state_names.keys():
#         state_city_dict[state_names[key]] = state_city_dict.values()


state_city_dict = dict((state_names[key],value) for (key,value) in state_city_dict.items())

# %%
for key in state_city_dict:
    state_city_dict[key] = list(set(state_city_dict[key]))

# %%
state_city_dict
# Out:
# {'ALBERTA': ['NW EDMONTON',
#   'EAST EDMONTON',
#   'SHERWOOD',
#   'BEAUMONT',
#   'EDMONTON',
#   'SAINT ALBERT',
#   'SOUTHEAST EDMONTON',
#   'WEST EDMONTON',
#   'ST. ALBERT',
#   'ST ALBERT',
#   'DOWNTOWN',
#   'EAUX CLAIRES',
#   'SHERWOOD PARK',
#   'ENOCH'],
#  'ARIZONA': ['GREEN VALLEY',
#   'ORO VALLEY',
#   'CORONA DE TUCSON',
#   'SOUTH TUCSON',
#   'TUSCON',
#   'VAIL',
#   'MARANA',
#   'TUCSON',
#   'MOUNT LEMMON',
#   'VALENCIA WEST',
#   'CATALINA',
#   'DREXEL HEIGHTS',
#   'SAHUARITA',
#   'CASAS ADOBES',
#   'PICTURE ROCKS'],
#  'CALIFORNIA': ['SANTA  BARBARA',
#   'MONTECITO',
#   'GOLETA',
#   'TRUCKEE',
#   'SANTA BARBARA',
#   'ISLA VISTA',
#   'SUMMERLAND',
#   'CARPINTERIA'],
#  'DELAWARE': ['ASTON',
#   'MARSHALLTON',
#   'CHRISTIANA',
#   'TROLLEY SQUARE',
#   'PIKE CREEK',
#   'GLEN MILLS',
#   'MONTCHANIN',
#   'NEWPORT',
#   'STANTON',
#   'NEW CASTLE',
#   'TALLEYVILLE',
#   'WILMINGTON',
#   'WILMINGTON ',
#   'HOCKESSIN',
#   'ELSMERE',
#   'NEWARK',
#   'WILMINGTON MANOR',
#   'GREENVILLE',
#   'CLAYMONT'],
#  'FLORIDA': ['DUNEDIN',
#   'SAINTT PETERSBURG',
#   'LARGO',
#   'TOWN N COUNTRY',
#   'TIERRE VERDE',
#   'SAN ANTONIO',
#   'CLEARWATER BEACH',
#   'RIVERVIEW',
#   'LUTZ',
#   'PINELLAS PARK',
#   'CLEARWATER',
#   'SOUTH TAMPA',
#   'BAYONET POINT',
#   'TEMPLE TERRACE',
#   'TREASURE ISLAND',
#   'ST PETE',
#   'ST PETE BEACH',
#   'N REDNGTN BCH',
#   'SUN CITY',
#   'HERNANDO BEACH',
#   'DADE CITY',
#   'CARROLLWOOD',
#   'OLDSMAR',
#   'ST. PETERSBURG',
#   'ST.PETERSBURG',
#   'NORTH REDINGTON BEACH',
#   'NORTH REDINGTON BCH',
#   'THONOSASSA',
#   'NEW PORT RICHEY',
#   'SAFETY HARBOR',
#   'HOLIDAY',
#   'CITRUS PARK',
#   'SUN CITY CENTER',
#   'BRANDON',
#   'TAMPA,FL',
#   'HUDSON',
#   'TRINITY',
#   'INDIAN SHORES',
#   'WYNDLAKE CONDOMINIUM',
#   'MANGO',
#   'MADEIRA BEACH',
#   'BELLEAIR BLF',
#   'RIVERVIEW FL',
#   'REDINGTON SHORES',
#   'PALM HARBOR',
#   'LAND O LAKES',
#   'HILLSBOROUGH COUNTY',
#   'SPRINGHILL',
#   'SOUTH PASADENA',
#   'TIERRA VERDE',
#   'MASARYKTOWN',
#   'ST PETERSBURG',
#   'SAINT PETERSBURG BEACH',
#   'WESLEY CHAPEL',
#   'SEFFNER',
#   'CLEARWATER/ COUNTRYSIDE',
#   'REDINGTON SHORE',
#   'SAINT PETE BEACH',
#   'VALRICO',
#   'THONOTOSASSA',
#   'SEMINOLE',
#   'ST PETERSURG',
#   "TOWN 'N' COUNTRY",
#   'BELLEAIR BLUFFS',
#   'ST. PETE BEACH',
#   'INDIAN ROCKS BEACH',
#   'ZEPHYRHILLS',
#   'PASS-A-GRILLE BEACH',
#   "LAND O'LAKES",
#   'LUTZ FL',
#   'SPRING HILL',
#   'PINECREST WEST PARK',
#   'APOLLO BEACH',
#   'OZONA',
#   'LITHIA',
#   'TAMPA PALMS',
#   'DOVER',
#   'TAMPA',
#   'BALM',
#   'KENNETH CITY',
#   'SAINT PETERSBURG',
#   'GREATER NORTHDALE',
#   'SAINT LEO',
#   'PLANT CITY',
#   'GIBSONTON',
#   'RUSKIN',
#   'TWN N CNTRY',
#   'TAMPA BAY',
#   'KENNETH',
#   'GULFPORT',
#   'HERNANDO BCH',
#   'S.PASADENA',
#   'WIMAUMA',
#   'TEMPLE TERR',
#   'PORT RICHEY',
#   "LAND O' LAKES",
#   'ST. LEO',
#   'LARGO (WALSINGHAM)',
#   'TARPON SPRINGS',
#   'ODESSA',
#   'PALMETTO',
#   'REDINGTN SHOR',
#   'TAMPA FLORIDA',
#   'WESTCHASE',
#   'PINELLAS',
#   'SOUTHWEST TAMPA'],
#  'IDAHO': ['GARDEN CITY',
#   'BOISE',
#   'NAMPA',
#   'KUNA',
#   'MERIDIAN',
#   'MERIDIAN ',
#   'EAGLE',
#   'BOISE CITY'],
#  'ILLINOIS': ['FAIRVIEW HTS.',
#   'EAST ST. LOUIS',
#   'ROSEWOOD HEIGHTS',
#   'SCOTT AIR FORCE BASE',
#   'CAHOKIA',
#   'GRANITE CITY',
#   'MASCOUTAH',
#   'EAST ALTON',
#   'GODFREY',
#   'COTTAGE HILLS',
#   'WATERLOO',
#   'DUPO',
#   'SCOTT AFB',
#   'SAUGET',
#   'BETHALTO',
#   "O'FALLON",
#   'EAST ST LOUIS',
#   'COLUMBIA',
#   'FAIRVIEW HTS',
#   'EAST SAINT LOUIS',
#   'CASEYVILLE',
#   'TROY',
#   'COLLINSVILLE',
#   "O' FALLON",
#   'FREEBURG',
#   'ALTON',
#   'WOOD RIVER',
#   'PONTOON BEACH',
#   'FOSTER POND',
#   'MADISON',
#   'BELLEVILLE',
#   'FAIRMONT CITY',
#   'EDWARDSVILLE',
#   'WASHINGTON PARK',
#   'SWANSEA',
#   'MARYVILLE',
#   'LEBANON',
#   'BELLVILLE',
#   'SHILOH',
#   'SMITHTON',
#   'ST. LOUIS',
#   'GLEN CARBON',
#   'FAIRVIEW HEIGHTS',
#   'O FALLON',
#   'MILLSTADT'],
#  'INDIANA': ['INDIANOPOLIS',
#   'NOBLESVILLE',
#   'FISHERS',
#   'GREENWOOD',
#   'NEW PALESTINE',
#   'CLERMONT',
#   'WANAMAKER',
#   'HANCOCK',
#   'SPEEDWAY',
#   'FRANKLIN',
#   'SOUTHPORT',
#   'ZIONSVILLE',
#   'INDIANAPOLIS ',
#   'FORTVILLE',
#   'LAWRENCE',
#   'BARGERSVILLE',
#   'WHITESTOWN',
#   'PLEASANT TOWNSHIP',
#   'INPOLIS',
#   'LAWRENCE TOWNSHIP',
#   'DANVILLE',
#   'WHITELAND',
#   'CASTLETON',
#   'INDIANAPOLIS',
#   'MARTINSVILLE',
#   'BOONE',
#   'INDIANA',
#   'CUMBERLAND',
#   'MCCORDSVILLE',
#   'CARMEL',
#   'MC CORDSVILLE',
#   'PLAINFILED',
#   'PLAINFIELD',
#   'GREENFIELD',
#   'BROWNSBURG',
#   'AVON',
#   'CAMBY',
#   'BEECH GROVE',
#   'NEW WHITELAND',
#   'MOORESVILLE'],
#  'LOUISIANA': ['GRETNA',
#   'ELMWOOD',
#   'HARVEY',
#   'WESTWEGO',
#   'RIVER RIDGE',
#   'KENNER',
#   'BYWATER',
#   'BRIDGE CITY',
#   'METAIRIE',
#   'ST. ROSE',
#   'ST.ROSE',
#   'AVONDALE',
#   'HARAHAN',
#   'MERAUX',
#   'GENTILLY',
#   'BELLE CHASE',
#   'TERRYTOWN',
#   'NEW ORLEANS',
#   'CHALEMETTE',
#   'JEFFERSON',
#   'CHALMETTE',
#   'LULING',
#   'MARRERO',
#   'SAINT ROSE',
#   'SAINT BERNARD',
#   'ARABI',
#   'RIVERIDGE',
#   'DOWNTOWN',
#   'BELLE CHASSE',
#   'BUCKTOWN',
#   'ALGIERS',
#   'METARIE',
#   'VIOLET'],
#  'MISSOURI': ['ST LOUIS COUNTY',
#   'BEL RIDGE',
#   'EARTH CITY',
#   'ARNOLD',
#   'TOWN AND COUNTRY ',
#   'FERGUSON',
#   'ST LOUIS',
#   'WARSON WOODS',
#   'FRONTENAC',
#   'BELLEFONTAINE NEIGHBORS',
#   'DES PERES',
#   'BLACK JACK',
#   'BRECKENRIDGE HILLS',
#   'WOODSON TERRACE',
#   'SAPPINGTON',
#   'ST. PETERS',
#   'WINCHESTER',
#   'VALLEY PARK',
#   'SAINT CHARLES',
#   'TOWN & COUNTRY',
#   'SHREWSBURY',
#   'DELLWOOD',
#   'CLAYTON',
#   'CHESTERFIELD',
#   'HAZELWOOD',
#   'HIGH RIDGE',
#   'LEMAY',
#   'KIRKWOOD',
#   'ST. LOUIS COUNTY',
#   'MARLBOROUGH',
#   'MEHLVILLE',
#   'BRENTWOOD',
#   'WEBSTER GROVES',
#   'MANCHESTER',
#   'ST.LOUIS',
#   'KIMMSWICK',
#   'ROCK HILL',
#   'MARYLAND HEIGHTS',
#   'CRESTWOOD',
#   'OVERLAND',
#   'BERKELEY',
#   'ST.ANN',
#   'SAINT LOUIS',
#   'ST. CHARLES',
#   'ST.CHARLES',
#   'UNIVERSITY CITY',
#   'BRIDGETON',
#   'GLENDALE',
#   'IMPERIAL',
#   'TOWN AND COUNTRY',
#   'CREVE COEUR',
#   'ST ANN',
#   'SAINT JOHN',
#   'ST. LOUIS',
#   'RICHMOND HEIGHTS',
#   'LADUE',
#   'TWIN OAKS',
#   'ST. ANN',
#   'AFFTON',
#   'ST CHARLES',
#   'PEERLESS PARK',
#   'JENNINGS',
#   'OAKVILLE',
#   'SAINT LOUIS,',
#   'ST.  CHARLES',
#   'SUNSET HILLS',
#   'GREEN PARK',
#   'OLIVETTE',
#   'SULLIVAN',
#   'BELLEFONTAINE',
#   'BLVD',
#   'BALLWIN',
#   'SAINT ANN',
#   'FLORISSANT',
#   'NORMANDY',
#   'ST LOUIS DOWNTOWN',
#   'MAPLEWOOD',
#   'FENTON'],
#  'NEW JERSEY': ['SWEDESBORO',
#   'WOODSTOWN',
#   'CLARKSBORO',
#   'HADDON HEIGHTS',
#   'TURNERSVILLE',
#   'SEWELL',
#   'WEST TRENTON',
#   'WOOLWICH TOWNSHIP',
#   'LOGAN TOWNSHIP',
#   'MT LAUREL',
#   'BERLIN',
#   'DEPTFORD TOWNSHIP',
#   'WATERFORD WORKS',
#   'AUDUBON',
#   'HADDON TWP',
#   'EVESHAM',
#   'MT.LAUREL',
#   'PENNSAUKEN TOWNSHIP',
#   'TRENTON',
#   'SOUTHAMPTON TOWNSHIP',
#   'MAPLE SHADE TOWNSHIP',
#   'AUDUBON ',
#   'GLOUCESTER TOWNSHIP',
#   'LAWNSIDE',
#   'MOUNT EPHRAIM',
#   'WASHINGTON TOWNSHIP',
#   'WILLIAMSTOWN',
#   'WESTMONT',
#   'MT HOLLY',
#   'COLUMBUS',
#   'OAKLYN',
#   'HADDON TOWNSHIP',
#   'UPPER PITTSGROVE',
#   'BURLINGTON',
#   'ROEBLING',
#   'RIVERSIDE',
#   'MT. HOLLY',
#   'BLACKWOOD ',
#   'DELRAN TWP',
#   'ELMER',
#   'SOMERDALE',
#   'MAPLE SHADE',
#   'TREN',
#   'WEST MOUNT HOLLY',
#   'MOUNT HOLLY,',
#   'WEST BERLIN',
#   'WILLINGBORO',
#   'FRANKLIN',
#   'EVESHAM TOWNSHIP',
#   'PINE HILL',
#   'MANTUA TOWNSHIP',
#   'CLAYTON',
#   'PEMBERTON',
#   'THOROFARE',
#   'ELK TOWNSHIP',
#   'W. BERLIN',
#   'W CHERRY HILL',
#   'LAWRENCE',
#   'MONROEVILLE',
#   'JOBSTOWN',
#   'CEDAR BROOK',
#   'WEST DEPTFORD TOWNSH',
#   'WESTAMPTON',
#   'RIVERTON',
#   'TITUSVILLE',
#   'MOUNT LAUREL TOWNSHIP',
#   'DELRAN',
#   'DEPTFORD',
#   'MANSFIELD',
#   'HAMMONTON',
#   'PENNSAUKEN',
#   'MT LAUREL TWP, NJ',
#   'FIELDSBORO',
#   'WENONAH',
#   'WOOLWICH TWP.',
#   'ATCO',
#   'OLDMANS TOWNSHIP',
#   'WASHINGTON TWP',
#   'EDGEWATER PARK',
#   'VINELAND',
#   'PILESGROVE',
#   'CARNEYS POINT',
#   'NEWFIELD',
#   'MULLICA HILL',
#   'BLACKWOOD',
#   'MOUNT HOLLY',
#   'STRATFORD',
#   'MT. LAUREL',
#   'WOODBURY HTS.',
#   'PENNSVILLE TOWNSHIP',
#   'VOORHEES',
#   'LAUREL SPRINGS',
#   'BURLINGTON TOWNSHIP',
#   'PALMYRA',
#   'EASTAMPTON TOWNSHIP',
#   'ALLOWAY',
#   'VOORHEES TOWNSHIP',
#   'BARRINGTON',
#   'PITTSGROVE',
#   'GLOUCESTER',
#   'NATIONAL PARK',
#   'LINDENWOLD',
#   'CHERRY HILL',
#   'FLORENCE TOWNSHIP',
#   'EWING',
#   'WEST DEPTFORD',
#   'BELLMAWR',
#   'FLANDERS',
#   'QUINTON',
#   'COLLINGSWOOD',
#   'TABERNACLE',
#   'MOUNT ROYAL',
#   'BRIDGETON',
#   'LAWRENCE TOWNSHIP',
#   "CARNEY'S POINT",
#   'MERCERVILLE',
#   'HAINESPORT',
#   'VINCENTOWN',
#   'RUNNEMEDE',
#   'MOORESTOWN',
#   'BORDENTOWN',
#   'PITTSGROVE TOWNSHIP',
#   'EASTAMPTON',
#   'BEVERLY',
#   'HAMILTION',
#   'DELRAN TOWNSHIP',
#   'FLORENCE',
#   'SHAMONG',
#   'CINNAMINSON',
#   'WESTVILLE',
#   'HARRISON TOWNSHIP',
#   'WESTMONT - HADDON TOWSSHIP',
#   'WESTHAMPTON',
#   'FREEHOLD',
#   'GIBBSBORO',
#   'GLOUCESTER CITY',
#   'FRANKLINVILLE',
#   'MANTUA',
#   'HADDONFIELD',
#   'MOUNT LAUREL',
#   'HAMILTON TOWNSHIP',
#   'MONROE TOWNSHIP',
#   'GIBBSTOWN',
#   'SOUTHAMPTON',
#   'MOORESTOWN-LENOLA',
#   'WEST COLLINGSWOOD HEIGHTS',
#   'MEDFORD',
#   'PENNSVILLE',
#   'HAMILTON',
#   'EWING TOWNSHIP',
#   'DELANCO',
#   'MALAGA',
#   'CEDARBROOK',
#   'HILLTOP',
#   'WOOLWICH TWP',
#   'GLENDORA',
#   'SALEM',
#   'HI-NELLA',
#   'SICKLERVILLE',
#   'LAMBERTVILLE',
#   'PITMAN',
#   'CAMDEN',
#   'PENNS GROVE',
#   'GLASSBORO',
#   'LUMBERTON',
#   'WILLINGBORO TOWNSHIP',
#   'WESTAMPTON TOWNSHIP',
#   'SOUTH CINNAMINSON',
#   'LAWRENCEVILLE',
#   'CLEMENTON',
#   'PENNINGTON',
#   'WOODBURY HEIGHTS',
#   'MAGNOLIA',
#   'PAULSBORO',
#   'BERLIN TOWNSHIP',
#   'WOODBURY',
#   'ERIAL',
#   'BROOKLAWN',
#   'CHESILHURST',
#   'WINSLOW TOWNSHIP',
#   'FOLSOM',
#   'HURFFVILLE',
#   'MARLTON',
#   'MERCHANTVILLE',
#   'MEDFORD LAKES'],
#  'NEVADA': ['VIRGINIA CITY',
#   'VERDI',
#   'COLD SPRINGS',
#   'SPARKS',
#   'SPANISH SPRINGS',
#   'SUN VALLEY',
#   'MOUNT LAUREL',
#   'RENO',
#   'STEAD'],
#  'PENNSYLVANIA': ['OAKS',
#   'GILBERTSVILLE',
#   'LINWOOD',
#   'DUBLIN',
#   'WYCOMBE',
#   'LIMA',
#   'UPPER MORELAND',
#   'PHILA',
#   'NEWPORTVILLE',
#   'HOLICONG',
#   'FESTERVILLE',
#   'RADNOR',
#   'AUDUBON',
#   'WYNNEWOOD',
#   'BRIDGEPORT',
#   'MIDDLETOWN',
#   'QUAKERTOWN',
#   'TROOPER',
#   'DOWNINGTOWN',
#   'DOYLESTOWN',
#   'BOYERTOWN',
#   'SOLEBURY',
#   'WALLINGFORD',
#   'WEST CHESTER',
#   'POTTSTOWN',
#   'NORRISTOWN',
#   'HULMEVILLE',
#   'LEDERACH',
#   'EAST GREENVILLE',
#   'ROCKLEDGE',
#   'MENDENHALL',
#   'SKIPPACK VILLAGE',
#   'THORNDALE',
#   'NEWTON',
#   'NEW HOPE',
#   'MONTGOMERY',
#   'CRUM LYNNE',
#   'ROSEMONT',
#   'PRIMOS',
#   'MARCUS HOOK',
#   'SWARTHMORE',
#   'ROYERSFORD',
#   'ST. DAVIDS',
#   'GLENMOORE',
#   'BROOKHAVEN',
#   'KULPSVILLE',
#   'HILLTOWN',
#   'WYNDMOOR',
#   'WEST CHESTER PA',
#   'MAPLE GLEN',
#   'DEVON',
#   'SWEDELAND',
#   'SELLERSVILLE',
#   'FORT WASHINGTON',
#   'HATFIELD',
#   'UPPER GWYNEDD',
#   'CONSHOHOCKEN',
#   'SUMNEYTOWN',
#   'ARDMORE',
#   'EDGEMONT',
#   'BELMONT HILLS',
#   'MILMONT PARK',
#   'PIPERSVILLE',
#   'DRESHER',
#   'PENNDEL',
#   'PERKIOMENVILLE',
#   'N.WALES',
#   'SOUTHWEST PHILADELPHIA',
#   'BLUE BELL',
#   'FOLCROFT',
#   'PHILADELPHIA ',
#   'NEWTOWN SQUARE',
#   'BUCKINGHAM',
#   'SASSAMANSVILLE',
#   'CROYDON',
#   'TRAINER',
#   'RICHBORO',
#   'PLYMOUTH MEETING',
#   'WYNCOTE',
#   'SAINT PETERS',
#   'BALA CYNWYD',
#   'WORCESTER',
#   'JAMISON',
#   'ABINGTON',
#   'FEASTERVILLE-TREVOSE',
#   'HOLLAND SOUTHAMPTON',
#   'WEST POINT',
#   'FRAZER',
#   'LOWER MERION',
#   'FAIRVIEW VILLAGE',
#   'GLENSIDE',
#   'VILLANOVA',
#   'WARRINGTON',
#   'TREVOSE',
#   'PLUMSTEADVILLE',
#   'NEW BRITAIN',
#   'WEST BRADFORD TOWNSHIP',
#   'PHILADELPHIA',
#   'NEWTOWN',
#   'MORRISVILLE',
#   'HAVERTOWN',
#   'SILVERDALE',
#   'CHESTERBROOK',
#   'ZIEGLERVILLE',
#   'FEASTERVILLE',
#   'CHESTER SPRINGS',
#   'WRIGHTSTOWN',
#   'COATESVILLE',
#   'LINE LEXINGTON',
#   'CHICHESTER',
#   'KIRKLYN',
#   'GULPH MILLS',
#   'LANSDOWNE',
#   'CONSHOHOEKEN',
#   'WESTTOWN',
#   'GARNET VALLEY',
#   'KIMBERTON',
#   'HARLEYSVILLE',
#   'JENKINTOWN',
#   'EDDINGTON',
#   'HATBORO',
#   'SCHWENKSVILLE',
#   'CLIFTON HEIGHTS',
#   'LEVITTOWN',
#   'COLLINGDALE',
#   'HORSHAM',
#   'IVYLAND',
#   'LIONVILLE',
#   'DARBY',
#   'WAYNE',
#   'LANGHORNE',
#   'PARKSIDE',
#   'BENSALEM TOWNSHIP',
#   'ORELAND',
#   'ABINGTON TOWNSHIP',
#   'WEST CONSHOHOCKEN',
#   'FURLONG',
#   'LESTER',
#   'BRISTOL',
#   'MELROSE PARK',
#   'CARVERSVILLE',
#   'LOWER PROVIDENCE',
#   'FLOURTOWN',
#   'CHALFONT',
#   'PHOENIXVILLE',
#   'EXTON',
#   'SPRING HOUSE',
#   'GLADWYNE',
#   'SPRING CITY',
#   'COLMAR',
#   'SKIPPACK',
#   'NORWOOD',
#   'UPPER DARBY',
#   'EDDYSTONE',
#   'WILLOW GROVE',
#   'BRISTOL TWP',
#   'SOUDERTON',
#   'CENTER SQUARE',
#   'BETHEL',
#   'EAST NORRITON',
#   'BUCKS',
#   'STOWE',
#   'UPPER POTTSGROVE',
#   'SECANE',
#   'HAVERFORD',
#   'CALN',
#   'TELFORD',
#   'GLENOLDEN',
#   'LIMERICK',
#   'DREXEL HILL',
#   'BIRCHRUNVILLE',
#   'LINFIELD',
#   'BLOOMING GLEN',
#   'EAST FALLS',
#   'HUNTINGDON VALLEY',
#   'YEADON',
#   'SHARON HILL',
#   'BENSALEM',
#   'TINICUM',
#   'BENSALEM. PA',
#   'TOUGHKENAMON',
#   'MONTGOMERYVILLE',
#   'PAOLI',
#   'JEFFERSONVILLE',
#   'PINE FORGE',
#   'TELFORD ',
#   'ROYERSFORD ',
#   'YARDLEY',
#   'TRAPPE',
#   'KING OF PRUSSIA',
#   'GWYNEDD',
#   'PENNSYLVANIA',
#   'BROOMALL',
#   'SPRINGFIELD',
#   'BERWYN',
#   'ELKINS PARK',
#   'LOWER SOUTHAMPTON TOWNSHIP',
#   'ERDENHEIM',
#   'LAHASKA',
#   'PERKASIE',
#   'FRANCONIA',
#   'MERION STATION',
#   'CHADDS FORD',
#   'BETHEL TOWNSHIP',
#   'W.CHESTER',
#   'AMBLER',
#   'GARDENVILLE',
#   'CEDARS',
#   'LAFAYETTE HILL',
#   'PENNSBURG',
#   'MONT CLARE',
#   'WOODLYN',
#   'RIDLEY PARK',
#   'ASTON',
#   'BRYN ATHYN',
#   'CONCORD TOWNSHIP',
#   'SOUTHAMPTON',
#   'MANAYUNK',
#   'LANSDALE ',
#   'CHELTENHAM',
#   'FEASTERVILLE TREVOSE',
#   'MORTON',
#   'NARBERTH',
#   'UNIONVILLE',
#   'COLLEGEVILLE',
#   'GWYNEDD VALLEY',
#   'EAGLEVILLE',
#   'GLENOLDAN',
#   'PINEVILLE',
#   'HOLLYWOOD',
#   'LONDON GROVE',
#   'CHURCHVILLE',
#   'ROSLYN',
#   'LANSDALE',
#   'PHILADEPHIA',
#   'BOOTHWYN',
#   'GLEN MILLS',
#   'AVONDALE',
#   'CORNWELLS HEIGHTS',
#   'FOX STREET',
#   'EAST LANSDOWNE',
#   'CHELTENHAM TOWNSHIP',
#   'HOLLAND',
#   'TYLERSPORT',
#   'NORTH COVENTRY TOWNSHIP',
#   'MALVERN',
#   'RIDLEY',
#   'UPLAND',
#   'RED HILL',
#   'CHESTER',
#   'PHILLY',
#   'MEDIA',
#   'CHARLOTTE',
#   'E. NORRISTOWN',
#   'WARRINGTON TOWNSHIP',
#   'PROSPECT PARK',
#   'WARMINSTER',
#   'THORNTON',
#   'HOLMES',
#   'CONCORDVILLE',
#   'SANATOGA',
#   'ELVERSON',
#   'UPPER CHICHESTER',
#   'ALDAN',
#   'BRYN MAWR',
#   'ESSINGTON',
#   'GREEN LANE',
#   'NEWTOWN SQAURE',
#   'FOLSOM',
#   'WASHINGTON CROSSING',
#   'NORTH WALES',
#   'KENNETT SQUARE',
#   'FAIRLESS HILLS',
#   'UPPER SOUTHAMPTON'],
#  'TENNESSEE': ['GALLATIN',
#   'FRANKLIN',
#   'HENDERSONVILLE',
#   'WHITE HOUSE',
#   'NASHVILLE-DAVIDSON METROPOLITAN GOVERNMENT (BALANCE)',
#   'MOUNT JULIET',
#   'GOODLETTSVILLE',
#   'NOLENSVILLE',
#   'BELLEVUE',
#   'NASHVILLE ',
#   'BERRY HILL',
#   'GOODLETSVILLE',
#   'NASHVILLE',
#   'VIEW',
#   'ANTIOCH',
#   'FAIRVIEW',
#   'CANE RIDGE',
#   'ASHLAND CITY',
#   'SMYRNA',
#   'WHITES CREEK',
#   'MT JULIET',
#   'DONELSON',
#   'HERMITAGE',
#   'JOELTON',
#   'OLD HICKORY',
#   'PLEASANT VIEW',
#   'BRENTWOOD',
#   'MT.JULIET',
#   'MADISON',
#   'BELLE MEADE',
#   'KINGSTON SPRINGS',
#   'INGLEWOOD',
#   'SPRINGFIELD',
#   'MT. JULIET',
#   'LEBANON',
#   'CLARKSVILLE',
#   'GREENBRIER',
#   'ASHLAND',
#   'RURAL HILL',
#   'LA VERGNE',
#   'EAST NASHVILLE']}

# %%
import json

with open('state_city_dict.json', 'w') as json_file:
    json.dump(state_city_dict, json_file, indent=4)

# %% [markdown]
# # Avg Revie Score by State #

# %%
states_df = pd.read_csv("/Users/dima/code/Dimasaur/scorecast/notebooks/yelp_review_raw.csv")

# %%
states_df.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                                NaN
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
states_reviews = states_df.groupby('state')['stars'].mean().sort_values(ascending=False)
states_reviews
# Out:
# state
# MT     5.000000
# VT     4.500000
# UT     4.500000
# SD     4.500000
# HI     4.250000
# XMS    4.000000
# CO     4.000000
# CA     3.996733
# NV     3.736876
# ID     3.707634
# LA     3.679162
# FL     3.610957
# AZ     3.592010
# IN     3.588246
# PA     3.573019
# TN     3.571500
# MO     3.546092
# WA     3.500000
# NJ     3.459114
# AB     3.447515
# IL     3.369697
# DE     3.354967
# TX     2.875000
# MI     2.500000
# VI     2.500000
# NC     2.000000
# MA     1.250000
# Name: stars, dtype: float64
